# %% [markdown]
# ----
# # Tutorial for Evaluating Fairness in Binary Classification

# %% [markdown]
# ----
# ## Evaluating Your Own Model? Looking for a Template?
# **Please note: This notebook is intended as an introduction to and reference for evaluating the fairness of a set of machine learning models using FairMLHealth, and it is not designed to work with outside models.**
#
# We recommend using our [Template-BinaryClassificationAssessment](../templates/Template-BinaryClassificationAssessment.ipynb), which also has a useful example: [ Example-BinaryClassificationTemplate]( Example-BinaryClassificationTemplate.ipynb) if you are looking for a template into which you can insert existing models.
#
#
# ## Overview
#
# All machine learning models can be assumed to hold biases, just as all humans hold biases and as all humans fall ill at some point in their lives. The motivation that drives us to study and prevent the harm caused by human illness drives us to prevent the harm caused by innate biases. That means building models that provide fair representation for all demographics. This starts with measurement and evaluation.
#
# This notebook introduces concepts, methods, and libraries for measuring fairness in machine learning (ML) models as it relates to problems in healthcare. This is a revamped version of the tutorial presented at the [KDD 2020 Tutorial on Fairness in Machine Learning for Healthcare](../docs/publications/KDD2020-FairnessInHealthcareML-Slides.pptx), the notebook for which can be found here: [/docs/publications/KDD2020-FairnessInHealthcareML-TutorialNotebook.ipynb](../docs/publications/KDD2020-FairnessInHealthcareML-TutorialNotebook.ipynb).
#
# [Part 1](#part1) will frame the problem and introduce our hypothetical example predicting Length of Stay (LOS) based on a subset of the [MIMIC-III clinical database](https://mimic.physionet.org/gettingstarted/access/). In [Part 2](#part2) this baseline model is used as an example to evaluate and discuss common metrics like *Disparate Impact*, *Equalized Odds*, and *Consistency Scores*. Then, [Part 4] compares the results of the baseline model to results for other modeling approaches: one "unaware" version, a "fairness-aware" version, and a third version simply using a different standard machine learning algorithm.
#
# There are abundant other publications covering the theoretical basis for fairness metrics, and many resources both online and academic covering the details of specific fairness measures (See [References (bottom)](#references) and [Additional Resources (bottom)](#additional_resources), or [Our Resources Page](../docs/Measures_QuickReference.md) for just a few). Many of these otherwise excellent references stop short of discussing  edge cases and the practical and philosophical considerations raised when evaluating real models for real customers. Here we attempt to bridge that gap.
#
#
#
# ## Table of Contents
# [Part 1](#part1) - Framing the Problem
#
# [Part 2](#part2) - Evaluating the Baseline Model
#
# [Part 3](#part3) - Comparing Models
#
# [References](#references)
#
#
#
# ## Requirements
#
# To run this notebook, please install FairMLHealth using [the instructions posted in GitHub](https://github.com/KenSciResearch/fairMLHealth#installation_instructions). Some components of this notebook additionally require the [Fairlearn](https://github.com/fairlearn/fairlearn) package.
#
# The tutorial uses data from the MIMIC III Critical Care database, a freely accessible source of electronic health records from Beth Israel Deaconess Medical Center in Boston. To download the MIMIC III data, please use this link: [Access to MIMIC III](https://mimic.physionet.org/gettingstarted/access/) and save the data with the default directory name ("MIMIC"). No further action is required beyond remembering the download location, and you do not need to unzip any files.
#
# A basic knowledge of ML implementation in Python is assumed.

# %% [markdown]
# ----
# ----
# # Part 1 - Framing the Problem <a class = "anchor" id = "part1"></a>

# %%
# Standard Libraries
from IPython.display import Markdown, HTML
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from scipy import stats
import sys
import warnings

# Load Prediction Libraries
import sklearn.metrics as sk_metric
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Remove limit to the number of columns and column widths displayed by pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 0) # adjust column width as needed

# %% [markdown]
# ### Below are helper functions that make the tutorial easier to read

# %%
# Helpers from local folder
from fairmlhealth.tutorial_helpers import feature_table
from fairmlhealth.mimic_data import load_mimic3_example
from fairmlhealth.model_comparison import measure_model, compare_models
from fairmlhealth import reports
from fairmlhealth.reports import flag 


# Verify that all required packages are present
from fairmlhealth.utils import validate_notebook_requirements
validate_notebook_requirements()

# Functions and pointers to make this tutorial more colorful
ks_magenta = '#d00095'
ks_magenta_lt = '#ff05b8'
ks_purple = '#947fed'

# %% [markdown]
# ### Loading the MIMIC III Data Subset <a id="datasubset"></a>
#
# As mentioned above, the MIMIC-III data download contains a folder of zipped_files. The tutorial code in the [Data Subset](#datasubset) section below will automatically unzip and format all necessary data for these experiments, saving the formatted data in the same MIMIC folder. Simply enter the correct path of the MIMIC folder in the following cell to enable this feature. Your path should end with the directory "MIMIC".
#
# Example: path_to_mimic_data_folder = "~/data/MIMIC"

# %%
# path_to_mimic_data_folder = "[path to your downloaded data folder]"
path_to_mimic_data_folder = "~/data/MIMIC"

# %% [markdown]
# Example models in this notebook use data from all years of the MIMIC-III dataset for patients aged 65 and older. Data are imported at the encounter level with all additional patient identification dropped. All models include an "AGE" feature, simplified to 5-year bins, as well as Boolean diagnosis and procedure features categorized through the Clinical Classifications Software system ([HCUP](https://www.hcup-us.ahrq.gov/toolssoftware/ccs/ccs.jsp)). All features other than age are one-hot encoded and prefixed with their variable type (e.g. "GENDER_", "ETHNICITY_").

# %%
# Load data and keep a 10K observation subset to speed processing
df = load_mimic3_example(path_to_mimic_data_folder) 
df = df.sample(n=10000, random_state=42).reset_index(drop=True)

# Subset to ages 65+
df = df.loc[df['AGE'].ge(65), :]
df.drop('GENDER_F', axis=1, inplace=True) # Redundant with GENDER_M

# Display insights
display(feature_table(df))
print("\n\n", "Below is a scrollable version of the first five rows of data:")
display(df.head())
# Out:
#  This data subset has 4834 total observations and 648 input features
#   Raw Feature  Category Count (Encoded Features).
# 0  AGE         1
# 1  DIAGNOSIS   282
# 2  ETHNICITY   41
# 3  GENDER      1
# 4  INSURANCE   5
# 5  LANGUAGE    69
# 6  MARRIED     7
# 7  PROCEDURE   222
# 8  RELIGION    20
#  Below is a scrollable version of the first five rows of data:
#     ADMIT_ID   AGE  GENDER_M  ETHNICITY_AMERICAN INDIAN/ALASKA NATIVE  \
# 1   711100    80.0  1         0
# 3   699023    75.0  1         0
# 8   726828    75.0  0         0
# 11  681915    85.0  1         0
# 15  712680    75.0  1         0
#
#     ETHNICITY_AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGNIZED TRIBE  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_ASIAN  ETHNICITY_ASIAN - ASIAN INDIAN  \
# 1   0                0
# 3   0                0
# 8   0                0
# 11  0                0
# 15  0                0
#
#     ETHNICITY_ASIAN - CAMBODIAN  ETHNICITY_ASIAN - CHINESE  \
# 1   0                            0
# 3   0                            0
# 8   0                            0
# 11  0                            0
# 15  0                            0
#
#     ETHNICITY_ASIAN - FILIPINO  ETHNICITY_ASIAN - JAPANESE  \
# 1   0                           0
# 3   0                           0
# 8   0                           0
# 11  0                           0
# 15  0                           0
#
#     ETHNICITY_ASIAN - KOREAN  ETHNICITY_ASIAN - OTHER  ETHNICITY_ASIAN - THAI  \
# 1   0                         0                        0
# 3   0                         0                        0
# 8   0                         0                        0
# 11  0                         0                        0
# 15  0                         0                        0
#
#     ETHNICITY_ASIAN - VIETNAMESE  ETHNICITY_BLACK/AFRICAN  \
# 1   0                             0
# 3   0                             0
# 8   0                             0
# 11  0                             0
# 15  0                             0
#
#     ETHNICITY_BLACK/AFRICAN AMERICAN  ETHNICITY_BLACK/CAPE VERDEAN  \
# 1   0                                 0
# 3   0                                 0
# 8   0                                 0
# 11  0                                 0
# 15  0                                 0
#
#     ETHNICITY_BLACK/HAITIAN  ETHNICITY_CARIBBEAN ISLAND  \
# 1   0                        0
# 3   0                        0
# 8   0                        0
# 11  0                        0
# 15  0                        0
#
#     ETHNICITY_HISPANIC OR LATINO  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_HISPANIC/LATINO - CENTRAL AMERICAN (OTHER)  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_HISPANIC/LATINO - COLOMBIAN  ETHNICITY_HISPANIC/LATINO - CUBAN  \
# 1   0                                      0
# 3   0                                      0
# 8   0                                      0
# 11  0                                      0
# 15  0                                      0
#
#     ETHNICITY_HISPANIC/LATINO - DOMINICAN  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_HISPANIC/LATINO - GUATEMALAN  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_HISPANIC/LATINO - HONDURAN  ETHNICITY_HISPANIC/LATINO - MEXICAN  \
# 1   0                                     0
# 3   0                                     0
# 8   0                                     0
# 11  0                                     0
# 15  0                                     0
#
#     ETHNICITY_HISPANIC/LATINO - PUERTO RICAN  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_HISPANIC/LATINO - SALVADORAN  ETHNICITY_MIDDLE EASTERN  \
# 1   0                                       0
# 3   0                                       0
# 8   0                                       0
# 11  0                                       0
# 15  0                                       0
#
#     ETHNICITY_MULTI RACE ETHNICITY  \
# 1   0
# 3   0
# 8   0
# 11  0
# 15  0
#
#     ETHNICITY_NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER  ETHNICITY_OTHER  \
# 1   0                                                    0
# 3   0                                                    0
# 8   0                                                    0
# 11  0                                                    0
# 15  0                                                    0
#
#     ETHNICITY_PATIENT DECLINED TO ANSWER  ETHNICITY_PORTUGUESE  \
# 1   0                                     0
# 3   0                                     0
# 8   0                                     0
# 11  0                                     0
# 15  0                                     0
#
#     ETHNICITY_SOUTH AMERICAN  ETHNICITY_UNABLE TO OBTAIN  \
# 1   0                         0
# 3   0                         0
# 8   0                         0
# 11  0                         0
# 15  0                         0
#
#     ETHNICITY_UNKNOWN/NOT SPECIFIED  ETHNICITY_WHITE  \
# 1   0                                1
# 3   1                                0
# 8   0                                1
# 11  0                                1
# 15  0                                1
#
#     ETHNICITY_WHITE - BRAZILIAN  ETHNICITY_WHITE - EASTERN EUROPEAN  \
# 1   0                            0
# 3   0                            0
# 8   0                            0
# 11  0                            0
# 15  0                            0
#
#     ETHNICITY_WHITE - OTHER EUROPEAN  ETHNICITY_WHITE - RUSSIAN  \
# 1   0                                 0
# 3   0                                 0
# 8   0                                 0
# 11  0                                 0
# 15  0                                 0
#
#     LANGUAGE_* BE  LANGUAGE_* FU  LANGUAGE_** T  LANGUAGE_**SH  LANGUAGE_**TO  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*AMH  LANGUAGE_*ARA  LANGUAGE_*ARM  LANGUAGE_*BEN  LANGUAGE_*BOS  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*BUL  LANGUAGE_*BUR  LANGUAGE_*CAN  LANGUAGE_*CDI  LANGUAGE_*CHI  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*DEA  LANGUAGE_*DUT  LANGUAGE_*FAR  LANGUAGE_*FIL  LANGUAGE_*FUL  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*GUJ  LANGUAGE_*HUN  LANGUAGE_*IBO  LANGUAGE_*KHM  LANGUAGE_*LEB  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*MAN  LANGUAGE_*MOR  LANGUAGE_*NEP  LANGUAGE_*PER  LANGUAGE_*PHI  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*PUN  LANGUAGE_*SPA  LANGUAGE_*TAM  LANGUAGE_*TOI  LANGUAGE_*TOY  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_*URD  LANGUAGE_*YID  LANGUAGE_*YOR  LANGUAGE_ALBA  LANGUAGE_AMER  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_ARAB  LANGUAGE_BENG  LANGUAGE_CAMB  LANGUAGE_CANT  LANGUAGE_CAPE  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_ENGL  LANGUAGE_ETHI  LANGUAGE_FREN  LANGUAGE_GREE  LANGUAGE_HAIT  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  1              0              0              0              0
#
#     LANGUAGE_HIND  LANGUAGE_ITAL  LANGUAGE_JAPA  LANGUAGE_KORE  LANGUAGE_LAOT  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_MAND  LANGUAGE_PERS  LANGUAGE_POLI  LANGUAGE_PORT  LANGUAGE_PTUN  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_RUSS  LANGUAGE_SERB  LANGUAGE_SOMA  LANGUAGE_SPAN  LANGUAGE_TAGA  \
# 1   0              0              0              0              0
# 3   0              0              0              0              0
# 8   0              0              0              0              0
# 11  0              0              0              0              0
# 15  0              0              0              0              0
#
#     LANGUAGE_THAI  LANGUAGE_TURK  LANGUAGE_URDU  LANGUAGE_VIET  \
# 1   0              0              0              0
# 3   0              0              0              0
# 8   0              0              0              0
# 11  0              0              0              0
# 15  0              0              0              0
#
#     INSURANCE_Government  INSURANCE_Medicaid  INSURANCE_Medicare  \
# 1   0                     0                   1
# 3   0                     0                   1
# 8   0                     0                   1
# 11  0                     0                   1
# 15  0                     0                   1
#
#     INSURANCE_Private  INSURANCE_Self Pay  MARRIED_DIVORCED  \
# 1   0                  0                   0
# 3   0                  0                   0
# 8   0                  0                   0
# 11  0                  0                   0
# 15  0                  0                   0
#
#     MARRIED_LIFE PARTNER  MARRIED_MARRIED  MARRIED_SEPARATED  MARRIED_SINGLE  \
# 1   0                     0                0                  0
# 3   0                     1                0                  0
# 8   0                     0                0                  1
# 11  0                     0                0                  0
# 15  0                     1                0                  0
#
#     MARRIED_UNKNOWN (DEFAULT)  MARRIED_WIDOWED  RELIGION_7TH DAY ADVENTIST  \
# 1   0                          1                0
# 3   0                          0                0
# 8   0                          0                0
# 11  0                          1                0
# 15  0                          0                0
#
#     RELIGION_BAPTIST  RELIGION_BUDDHIST  RELIGION_CATHOLIC  \
# 1   0                 0                  1
# 3   0                 0                  0
# 8   0                 0                  0
# 11  0                 0                  0
# 15  0                 0                  0
#
#     RELIGION_CHRISTIAN SCIENTIST  RELIGION_EPISCOPALIAN  \
# 1   0                             0
# 3   0                             0
# 8   0                             0
# 11  0                             0
# 15  0                             0
#
#     RELIGION_GREEK ORTHODOX  RELIGION_HEBREW  RELIGION_HINDU  \
# 1   0                        0                0
# 3   0                        0                0
# 8   0                        0                0
# 11  0                        0                0
# 15  0                        0                0
#
#     RELIGION_JEHOVAH'S WITNESS  RELIGION_JEWISH  RELIGION_LUTHERAN  \
# 1   0                           0                0
# 3   0                           0                0
# 8   0                           0                0
# 11  0                           0                0
# 15  0                           0                0
#
#     RELIGION_METHODIST  RELIGION_MUSLIM  RELIGION_NOT SPECIFIED  \
# 1   0                   0                0
# 3   0                   0                0
# 8   0                   0                0
# 11  0                   0                0
# 15  0                   0                0
#
#     RELIGION_OTHER  RELIGION_PROTESTANT QUAKER  RELIGION_ROMANIAN EAST. ORTH  \
# 1   0               0                           0
# 3   1               0                           0
# 8   0               0                           0
# 11  0               0                           0
# 15  0               1                           0
#
#     RELIGION_UNITARIAN-UNIVERSALIST  RELIGION_UNOBTAINABLE  DIAGNOSIS_CCS_0  \
# 1   0                                0                      0
# 3   0                                0                      0
# 8   0                                1                      0
# 11  0                                1                      0
# 15  0                                0                      0
#
#     DIAGNOSIS_CCS_1  DIAGNOSIS_CCS_2  DIAGNOSIS_CCS_3  DIAGNOSIS_CCS_4  \
# 1   0                0                0                0
# 3   0                0                0                0
# 8   0                0                0                0
# 11  0                0                0                0
# 15  0                0                0                0
#
#     DIAGNOSIS_CCS_5  DIAGNOSIS_CCS_6  DIAGNOSIS_CCS_7  DIAGNOSIS_CCS_8  \
# 1   0                0                0                0
# 3   0                0                0                0
# 8   0                0                0                0
# 11  0                0                0                0
# 15  0                0                0                0
#
#     DIAGNOSIS_CCS_9  DIAGNOSIS_CCS_10  DIAGNOSIS_CCS_11  DIAGNOSIS_CCS_12  \
# 1   0                0                 0                 0
# 3   0                0                 0                 0
# 8   0                0                 0                 0
# 11  0                0                 0                 0
# 15  0                0                 0                 0
#
#     DIAGNOSIS_CCS_13  DIAGNOSIS_CCS_14  DIAGNOSIS_CCS_15  DIAGNOSIS_CCS_16  \
# 1   0                 1                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 1
#
#     DIAGNOSIS_CCS_17  DIAGNOSIS_CCS_18  DIAGNOSIS_CCS_19  DIAGNOSIS_CCS_20  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_21  DIAGNOSIS_CCS_22  DIAGNOSIS_CCS_23  DIAGNOSIS_CCS_24  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_25  DIAGNOSIS_CCS_26  DIAGNOSIS_CCS_27  DIAGNOSIS_CCS_28  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_29  DIAGNOSIS_CCS_30  DIAGNOSIS_CCS_31  DIAGNOSIS_CCS_32  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_33  DIAGNOSIS_CCS_34  DIAGNOSIS_CCS_35  DIAGNOSIS_CCS_36  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_37  DIAGNOSIS_CCS_38  DIAGNOSIS_CCS_39  DIAGNOSIS_CCS_40  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_41  DIAGNOSIS_CCS_42  DIAGNOSIS_CCS_43  DIAGNOSIS_CCS_44  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 1
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_45  DIAGNOSIS_CCS_46  DIAGNOSIS_CCS_47  DIAGNOSIS_CCS_48  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_49  DIAGNOSIS_CCS_50  DIAGNOSIS_CCS_51  DIAGNOSIS_CCS_52  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_53  DIAGNOSIS_CCS_54  DIAGNOSIS_CCS_55  DIAGNOSIS_CCS_56  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 1                 0
#
#     DIAGNOSIS_CCS_57  DIAGNOSIS_CCS_58  DIAGNOSIS_CCS_59  DIAGNOSIS_CCS_60  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_61  DIAGNOSIS_CCS_62  DIAGNOSIS_CCS_63  DIAGNOSIS_CCS_64  \
# 1   0                 0                 0                 0
# 3   0                 1                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 1                 0
#
#     DIAGNOSIS_CCS_76  DIAGNOSIS_CCS_77  DIAGNOSIS_CCS_78  DIAGNOSIS_CCS_79  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_80  DIAGNOSIS_CCS_81  DIAGNOSIS_CCS_82  DIAGNOSIS_CCS_83  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 1                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_84  DIAGNOSIS_CCS_85  DIAGNOSIS_CCS_86  DIAGNOSIS_CCS_87  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_88  DIAGNOSIS_CCS_89  DIAGNOSIS_CCS_90  DIAGNOSIS_CCS_91  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_92  DIAGNOSIS_CCS_93  DIAGNOSIS_CCS_94  DIAGNOSIS_CCS_95  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  0                 0                 0                 0
#
#     DIAGNOSIS_CCS_96  DIAGNOSIS_CCS_97  DIAGNOSIS_CCS_98  DIAGNOSIS_CCS_99  \
# 1   0                 0                 0                 0
# 3   0                 0                 0                 0
# 8   0                 0                 0                 0
# 11  0                 0                 0                 0
# 15  1                 0                 1                 0
#
#     DIAGNOSIS_CCS_100  DIAGNOSIS_CCS_101  DIAGNOSIS_CCS_102  \
# 1   0                  0                  0
# 3   0                  1                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_103  DIAGNOSIS_CCS_104  DIAGNOSIS_CCS_105  \
# 1   0                  0                  0
# 3   0                  0                  1
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_106  DIAGNOSIS_CCS_107  DIAGNOSIS_CCS_108  \
# 1   1                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  1                  0                  1
# 15  1                  0                  0
#
#     DIAGNOSIS_CCS_109  DIAGNOSIS_CCS_110  DIAGNOSIS_CCS_111  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_112  DIAGNOSIS_CCS_113  DIAGNOSIS_CCS_114  \
# 1   0                  0                  0
# 3   0                  0                  1
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_115  DIAGNOSIS_CCS_116  DIAGNOSIS_CCS_117  \
# 1   1                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_118  DIAGNOSIS_CCS_119  DIAGNOSIS_CCS_120  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  1                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_121  DIAGNOSIS_CCS_122  DIAGNOSIS_CCS_123  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  1                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_124  DIAGNOSIS_CCS_125  DIAGNOSIS_CCS_126  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_127  DIAGNOSIS_CCS_128  DIAGNOSIS_CCS_129  \
# 1   1                  0                  0
# 3   0                  0                  0
# 8   1                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_130  DIAGNOSIS_CCS_131  DIAGNOSIS_CCS_132  \
# 1   0                  0                  0
# 3   1                  0                  0
# 8   0                  1                  0
# 11  0                  1                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_133  DIAGNOSIS_CCS_134  DIAGNOSIS_CCS_135  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_136  DIAGNOSIS_CCS_137  DIAGNOSIS_CCS_138  \
# 1   0                  0                  1
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_139  DIAGNOSIS_CCS_140  DIAGNOSIS_CCS_141  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_142  DIAGNOSIS_CCS_143  DIAGNOSIS_CCS_144  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  1
# 11  0                  0                  0
# 15  0                  0                  1
#
#     DIAGNOSIS_CCS_145  DIAGNOSIS_CCS_146  DIAGNOSIS_CCS_147  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_148  DIAGNOSIS_CCS_149  DIAGNOSIS_CCS_151  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  1
#
#     DIAGNOSIS_CCS_152  DIAGNOSIS_CCS_153  DIAGNOSIS_CCS_154  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_155  DIAGNOSIS_CCS_156  DIAGNOSIS_CCS_157  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_158  DIAGNOSIS_CCS_159  DIAGNOSIS_CCS_160  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_161  DIAGNOSIS_CCS_162  DIAGNOSIS_CCS_163  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_164  DIAGNOSIS_CCS_165  DIAGNOSIS_CCS_166  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_167  DIAGNOSIS_CCS_168  DIAGNOSIS_CCS_169  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_170  DIAGNOSIS_CCS_171  DIAGNOSIS_CCS_172  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_173  DIAGNOSIS_CCS_174  DIAGNOSIS_CCS_175  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_176  DIAGNOSIS_CCS_177  DIAGNOSIS_CCS_178  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_179  DIAGNOSIS_CCS_180  DIAGNOSIS_CCS_181  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_182  DIAGNOSIS_CCS_183  DIAGNOSIS_CCS_184  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_185  DIAGNOSIS_CCS_186  DIAGNOSIS_CCS_187  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_188  DIAGNOSIS_CCS_189  DIAGNOSIS_CCS_190  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_191  DIAGNOSIS_CCS_192  DIAGNOSIS_CCS_193  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_195  DIAGNOSIS_CCS_196  DIAGNOSIS_CCS_197  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_198  DIAGNOSIS_CCS_199  DIAGNOSIS_CCS_200  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  1                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_201  DIAGNOSIS_CCS_202  DIAGNOSIS_CCS_203  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_204  DIAGNOSIS_CCS_205  DIAGNOSIS_CCS_206  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_207  DIAGNOSIS_CCS_208  DIAGNOSIS_CCS_209  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_210  DIAGNOSIS_CCS_211  DIAGNOSIS_CCS_212  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_213  DIAGNOSIS_CCS_214  DIAGNOSIS_CCS_215  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_216  DIAGNOSIS_CCS_217  DIAGNOSIS_CCS_218  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_219  DIAGNOSIS_CCS_220  DIAGNOSIS_CCS_221  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_222  DIAGNOSIS_CCS_223  DIAGNOSIS_CCS_224  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_225  DIAGNOSIS_CCS_226  DIAGNOSIS_CCS_227  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_228  DIAGNOSIS_CCS_229  DIAGNOSIS_CCS_230  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_231  DIAGNOSIS_CCS_232  DIAGNOSIS_CCS_233  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  1                  0                  0
# 15  0                  0                  0
#
#     DIAGNOSIS_CCS_234  DIAGNOSIS_CCS_235  DIAGNOSIS_CCS_236  \
# ...
# 3   0                 0                 0                  0
# 8   0                 0                 0                  0
# 11  0                 0                 0                  0
# 15  0                 0                 0                  0
#
#     PROCEDURE_CCS_102  PROCEDURE_CCS_103  PROCEDURE_CCS_104  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_105  PROCEDURE_CCS_106  PROCEDURE_CCS_107  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_108  PROCEDURE_CCS_109  PROCEDURE_CCS_110  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_111  PROCEDURE_CCS_112  PROCEDURE_CCS_113  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_114  PROCEDURE_CCS_115  PROCEDURE_CCS_116  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_117  PROCEDURE_CCS_118  PROCEDURE_CCS_119  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_120  PROCEDURE_CCS_121  PROCEDURE_CCS_122  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_123  PROCEDURE_CCS_124  PROCEDURE_CCS_125  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_126  PROCEDURE_CCS_127  PROCEDURE_CCS_128  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_129  PROCEDURE_CCS_130  PROCEDURE_CCS_131  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_132  PROCEDURE_CCS_133  PROCEDURE_CCS_134  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_135  PROCEDURE_CCS_136  PROCEDURE_CCS_137  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_138  PROCEDURE_CCS_139  PROCEDURE_CCS_140  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_141  PROCEDURE_CCS_142  PROCEDURE_CCS_143  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  1                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_144  PROCEDURE_CCS_145  PROCEDURE_CCS_146  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_147  PROCEDURE_CCS_148  PROCEDURE_CCS_149  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_150  PROCEDURE_CCS_151  PROCEDURE_CCS_152  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_153  PROCEDURE_CCS_154  PROCEDURE_CCS_155  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_156  PROCEDURE_CCS_157  PROCEDURE_CCS_158  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  1
# 15  0                  0                  0
#
#     PROCEDURE_CCS_159  PROCEDURE_CCS_160  PROCEDURE_CCS_161  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_162  PROCEDURE_CCS_163  PROCEDURE_CCS_164  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_165  PROCEDURE_CCS_166  PROCEDURE_CCS_167  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_168  PROCEDURE_CCS_169  PROCEDURE_CCS_170  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_171  PROCEDURE_CCS_172  PROCEDURE_CCS_173  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_174  PROCEDURE_CCS_175  PROCEDURE_CCS_176  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_177  PROCEDURE_CCS_178  PROCEDURE_CCS_179  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_180  PROCEDURE_CCS_181  PROCEDURE_CCS_183  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_184  PROCEDURE_CCS_185  PROCEDURE_CCS_186  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_187  PROCEDURE_CCS_188  PROCEDURE_CCS_189  \
# 1   0                  0                  0
# 3   0                  1                  1
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_190  PROCEDURE_CCS_191  PROCEDURE_CCS_192  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_193  PROCEDURE_CCS_194  PROCEDURE_CCS_195  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_196  PROCEDURE_CCS_197  PROCEDURE_CCS_198  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_199  PROCEDURE_CCS_201  PROCEDURE_CCS_202  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_204  PROCEDURE_CCS_205  PROCEDURE_CCS_206  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_208  PROCEDURE_CCS_209  PROCEDURE_CCS_211  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_212  PROCEDURE_CCS_213  PROCEDURE_CCS_214  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_216  PROCEDURE_CCS_217  PROCEDURE_CCS_218  \
# 1   0                  0                  0
# 3   1                  0                  0
# 8   1                  0                  0
# 11  1                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_219  PROCEDURE_CCS_220  PROCEDURE_CCS_221  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_222  PROCEDURE_CCS_223  PROCEDURE_CCS_224  \
# 1   0                  0                  0
# 3   0                  0                  0
# 8   0                  0                  0
# 11  0                  1                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_225  PROCEDURE_CCS_226  PROCEDURE_CCS_227  \
# 1   0                  0                  0
# 3   0                  0                  1
# 8   0                  0                  0
# 11  0                  0                  0
# 15  0                  0                  0
#
#     PROCEDURE_CCS_228  PROCEDURE_CCS_229  PROCEDURE_CCS_231  length_of_stay
# 1   0                  0                  0                  6.281250
# 3   0                  0                  0                  21.741667
# 8   0                  0                  0                  2.754167
# 11  0                  0                  0                  13.761111
# 15  0                  0                  0                  1.152778

# %% [markdown]
# ### Generating the Model <a id="generatemodel"></a>

# %%
# Display LOS Distributions
ax = df.groupby('LANGUAGE_ENGL')['length_of_stay'
        ].plot(kind='kde', 
               title="Distribution of Length of Stay (in Days) Relative to English Language Status")
plt.show()

# %%
# Subset and Split Data
baseline_cols = [c for c in df.columns if (c.startswith('AGE') or c.startswith('DIAGNOSIS_') or c.startswith('PROCEDURE_') or c == "LANGUAGE_ENGL")]
X = df.loc[:, baseline_cols]
y = df['length_of_stay']

#
splits = train_test_split(X, y, test_size=0.33, random_state=42)
X_train, X_test, y_train, y_test = splits

# %%
# Train New Model with Language Feature
baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)
y_pred = baseline_model.predict(X_test)

# %% [markdown]
# ### FairMLHealth Stratified Data Reporter
#
# FairMLHealth includes stratified reporting features to aid in identifying the source of unfairness or other bias. The data reporter evaluates basic statistics specific to each feature-value, in addition to relative statistics for the target value. Since the reporter can evaluate many features at once, it can be a useful option for identifying patterns of bias either alone or in concert with other (e.g., visual methods).

# %%
print("FairMLHealth Stratified Data Report")
reports.data_report(X_test, y_test, features=['LANGUAGE_ENGL'])
# Out:
# FairMLHealth Stratified Data Report
#     Feature Name Feature Value    Obs.  Missing Values  Feature Entropy  \
# 0  ALL FEATURES   ALL VALUES    1596.0  0              NaN
# 1  LANGUAGE_ENGL  0             756.0   0               0.998
# 2  LANGUAGE_ENGL  1             840.0   0               0.998
#
#    Target Max  Target Mean  Target Median  Target Min  Target Std. Dev.  \
# 0  29.9125     8.9492       7.2740         0.0771      6.1026
# 1  29.9125     9.1437       7.3177         0.0771      6.2608
# 2  29.8854     8.7741       7.1948         0.1681      5.9548
#
#    Value Prevalence
# 0  1.0000
# 1  0.4737
# 2  0.5263

# %% [markdown]
# ----
# ----
# # Part 2 - Evaluating the Baseline Model <a id="part2"></a>
# In this section we will evaluate an array of fairness measures for a single model. For more information on how to interpret these results, see [Evaluating Fairness](docs/Evaluating_Fairness.md) in our documentation. Skip ahead to [Part 3](#part3) for an example comparing multiple models against each other.
#
# Our experiment tests sociodemographic bias as it relates to language. Here we suppose that individuals who speak English may be given preferential treatment in an English-speaking society due to the requirement of using a translator. Language may also be used as a proxy for race, religion, or nationality, which are [explicitly protected attributes](https://www.eeoc.gov/employers/small-business/3-who-protected-employment-discrimination).

# %%
lang_values = X_test['LANGUAGE_ENGL']

# %%
print("FairMLHealth Fairness Measure Report: English Language")
fairness_report = measure_model(X_test, y_test, lang_values, baseline_model, pred_type="regression")
reports.flag(fairness_report)
# Out:
# FairMLHealth Fairness Measure Report: English Language
# <style  type="text/css" >
# #T_11fba0f4_b1ed_11eb_9753_acde48001122row0_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row1_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row2_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row3_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row8_col0{
#             color: magenta;
#         }#T_11fba0f4_b1ed_11eb_9753_acde48001122row4_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row5_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row6_col0,#T_11fba0f4_b1ed_11eb_9753_acde48001122row7_col0{
#             color: magenta;
#             color: magenta;
#         }</style><table id="T_11fba0f4_b1ed_11eb_9753_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level0_row0" class="row_heading level0 row0" rowspan=8>Group Fairness</th>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row0" class="row_heading level1 row0" >Mean Prediction Ratio</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row1" class="row_heading level1 row1" >scMAE Ratio</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row2" class="row_heading level1 row2" >MAE Ratio</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row3" class="row_heading level1 row3" >Mean Error Ratio</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row4" class="row_heading level1 row4" >Mean Prediction Difference</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row4_col0" class="data row4 col0" >-755388891.352800</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row5" class="row_heading level1 row5" >scMAE Difference</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row5_col0" class="data row5 col0" >-25572177.228600</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row6" class="row_heading level1 row6" >MAE Difference</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row6_col0" class="data row6 col0" >-759937625.085100</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row7" class="row_heading level1 row7" >Mean Error Difference</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row7_col0" class="data row7 col0" >-755388891.722400</td>
#             </tr>
#             <tr>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level0_row8" class="row_heading level0 row8" rowspan=2>Individual Fairness</th>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row8" class="row_heading level1 row8" >Consistency Score</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row8_col0" class="data row8 col0" >-798722923.008500</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row9" class="row_heading level1 row9" >Between-Group Gen. Entropy Error</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row9_col0" class="data row9 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level0_row10" class="row_heading level0 row10" rowspan=6>Model Performance (Weighted Avg)</th>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row10" class="row_heading level1 row10" >Target Mean</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row10_col0" class="data row10 col0" >8.949200</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row11" class="row_heading level1 row11" >Pred. Mean</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row11_col0" class="data row11 col0" >397573110.366400</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row12" class="row_heading level1 row12" >scMAE</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row12_col0" class="data row12 col0" >13405784.779600</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row13" class="row_heading level1 row13" >MSE</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row13_col0" class="data row13 col0" >253778008040436531200.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row14" class="row_heading level1 row14" >MAE</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row14_col0" class="data row14 col0" >399967174.642100</td>
#             </tr>
#             <tr>
#                                 <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row15" class="row_heading level1 row15" >Rsqrd</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row15_col0" class="data row15 col0" >-6818705362174735360.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level0_row16" class="row_heading level0 row16" >Data Metrics</th>
#                         <th id="T_11fba0f4_b1ed_11eb_9753_acde48001122level1_row16" class="row_heading level1 row16" >Prevalence of Privileged Class (%)</th>
#                         <td id="T_11fba0f4_b1ed_11eb_9753_acde48001122row16_col0" class="data row16 col0" >0.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### FairMLHealth Stratified Performance Reporter
#
# The stratified performance reporter evaluates model performance specific to each feature-value subset. In this example we can see that the Equalized Odds ratio is out of range because of the significant difference in False Positive Rates (FPR) between the two classes. More about this difference in [Comparing Group Fairness Measures](#comparing_group_measures) below.
#
# Note that if prediction probabilities (via the *predict_proba()* method) are available to the model, additional ROC_AUC and PR_AUC values will be included in the report.

# %%
print("FairMLHealth Stratified Performance Report")
reports.performance_report(X_test, y_test, y_pred, features=['LANGUAGE_ENGL'], pred_type="regression")
# Out:
# FairMLHealth Stratified Performance Report
#     Feature Name Feature Value    Obs.  Target Mean    Pred. Mean  \
# 0  ALL FEATURES   ALL VALUES    1596.0  8.9492       3.975731e+08
# 1  LANGUAGE_ENGL  0             756.0   9.1437       9.654400e+00
# 2  LANGUAGE_ENGL  1             840.0   8.7741       7.553889e+08
#
#      Error Mean  Error Std. Dev.           MAE           MSE  Pred. Median  \
# 0  3.975731e+08  1.593044e+10     3.999672e+08  2.537780e+20  8.3053
# 1  5.107000e-01  4.773500e+00     3.544700e+00  2.301680e+01  8.6751
# 2  7.553889e+08  2.195863e+10     7.599376e+08  4.821782e+20  7.7549
#
#    Pred. Std. Dev.         scMAE
# 0  1.593044e+10     1.340578e+07
# 1  4.872300e+00     1.188000e-01
# 2  2.195863e+10     2.557218e+07

# %% [markdown]
# ### FairMLHealth Stratified Fairness Reporter
#
# The stratified bias reporter evaluates prediction bias specific to each feature-value subset. It assumes each feature-value as the "privileged" group relative to all other possible values for the feature. To simplify the report, fairness measures have been simplified to their component parts. For example, measures of Equalized Odds can be determined by combining the True Positive Rate (TPR) Ratios & Differences with False Positive Rate (FPR) Ratios & Differences.

# %%
from importlib import reload
reload(reports)
# Out:
# <module 'fairmlhealth.reports' from '/Users/christineallen/repos/fairMLHealth/fairmlhealth/reports.py'>

# %%
print("FairMLHealth Stratified Fairness Report")
reports.bias_report(X_test, y_test, y_pred, features=['LANGUAGE_ENGL'], pred_type="regression")
# Out:
# FairMLHealth Stratified Fairness Report
# /Users/christineallen/repos/fairMLHealth/fairmlhealth/reports.py:232: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[cohorts] = 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-6fa87f623153> in <module>
#       1 print("FairMLHealth Stratified Fairness Report")
# ----> 2 reports.bias_report(X_test, y_test, y_pred, features=['LANGUAGE_ENGL'], pred_type="regression")
#
# ~/repos/fairMLHealth/fairmlhealth/reports.py in bias_report(X, y_true, y_pred, features, pred_type, priv_grp, sig_dec, cohorts)
#     235             ixs = X[X[cohorts].eq(ch)].index
#     236             res.append(__regression_bias_report(X.loc[ixs], y_true.loc[ixs],
# --> 237                                                 y_pred.loc[ixs], features))
#     238         res_df = pd.concat(res, axis=0)
#     239         return res_df
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'

# %%
X_test['quantile'] = pd.qcut(y_test, 3, labels=False)

reports.bias_report(X_test, y_test, y_pred, features=['LANGUAGE_ENGL'], , pred_type="regression", cohorts='quantile')
